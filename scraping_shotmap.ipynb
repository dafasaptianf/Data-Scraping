# %%
import json
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path


from selenium import webdriver #selenium 4.20.0
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.common.exceptions import WebDriverException

from webdriver_manager.chrome import ChromeDriverManager
 # version 4.0.1

# %%
options = webdriver.ChromeOptions()
options.set_capability(
    "goog:loggingPrefs", {"performance": "ALL", "browser": "ALL"}
)

# Make sure you already have Chrome installed
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()), options=options)

# %%
driver.set_page_load_timeout(30)

try:
    driver.get("https://www.sofascore.com/spain-france/GObsYTb#id:11874020")
except:
    pass


driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
# extract requests from logs
logs_raw = driver.get_log("performance")
logs = [json.loads(lr["message"])["message"] for lr in logs_raw]

# %%
desired_keywords = ['shotmap']

for log in logs:
    # Check if the log contains the 'method' key
    if 'method' in log:
        # Check if the log method is 'Network.responseReceived'
        if log["method"] == "Network.responseReceived":
            # Extract request ID and URL
            request_id = log["params"]["requestId"]
            url = log["params"]["response"]["url"]
            # Check if the URL contains any of the desired keywords
            if any(keyword in url for keyword in desired_keywords):
                # Print the request ID and URL
                print(f"Request ID: {request_id}, URL: {url}")
                # # Try to retrieve the response body using the request ID
                try:
                    response = driver.execute_cdp_cmd('Network.getResponseBody', {'requestId': request_id})
                    stats = response['body']
                    if stats:
                        print("Response body successfully retrieved:")
                        print(stats)
                        break
                    else:
                        print("Response body is empty. Trying next request ID...")
                except Exception as e:
                    print(f"Error occurred while retrieving response for request ID {request_id}: {e}")
                    continue

# stats
# Out:
# Request ID: 9832.3283, URL: https://www.sofascore.com/api/v1/event/11874020/shotmap
# Response body successfully retrieved:
# {"shotmap":[{"player":{"name":"Antoine Griezmann","slug":"antoine-griezmann","shortName":"A. Griezmann","position":"F","jerseyNumber":"7","userCount":110394,"id":85859,"fieldTranslations":{"nameTranslation":{"ar":"\u063a\u0631\u064a\u0632\u0645\u0627\u0646, \u0627\u0646\u0637\u0648\u0627\u0646"},"shortNameTranslation":{"ar":"\u0627. \u063a\u0631\u064a\u0632\u0645\u0627\u0646"}}},"isHome":false,"shotType":"block","situation":"assisted","playerCoordinates":{"x":10.5,"y":58.3,"z":0},"bodyPart":"head","goalMouthLocation":"low-centre","goalMouthCoordinates":{"x":0,"y":49.4,"z":19},"blockCoordinates":{"x":9,"y":57.2,"z":0},"xg":0.02813040651381,"id":3433360,"time":90,"addedTime":5,"timeSeconds":5679,"draw":{"start":{"x":58.3,"y":10.5},"block":{"x":57.2,"y":9},"end":{"x":50.6,"y":0},"goal":{"x":50.6,"y":81}},"reversedPeriodTime":1,"reversedPeriodTimeSeconds":621,"incidentType":"shot"},{"player":{"name":"Kylian Mbapp\u00e9","slug":"kylian-mbappe","shortName":"K. Mbapp\u00e9","position":"F","jerseyNumber":"9","userCount":508440,"id":826643,"fieldTranslations":{"nameTranslation":{"ar":"\u0643\u064a\u0644\u064a\u0627\u0646 \u0645\u0628\u0627\u0628"},"shortNameTranslation":{"ar":"\u0643. \u0645\u0628\u0627\u0628"}}},"isHome":false,"shotType":"miss","situation":"assisted","playerCoordinates":{"x":14.1,"y":39,"z":0},"bodyPart":"right-foot","goalMouthLocation":"high","goalMouthCoordinates":{"x":0,"y":54.6,"z":66.7},"xg":0.079102113842964,"id":3433359,"time":86,"timeSeconds":5124,"draw":{"start":{"x":39,"y":14.1},"end":{"x":45.4,"y":0},"goal":{"x":45.4,"y":33.3}},"reversedPeriodTime":5,"reversedPeriodTimeSeconds":276,"incidentType":"shot"},{"player":{"name":"Lamine Yamal","firstName":"Lamine Yamal","slug":"lamine-yamal","shortName":"Lamine Yamal","position":"F","jerseyNumber":"27","userCount":164506,"id":1402912,"fieldTranslations":{"nameTranslation":{"ar":"\u0644\u0627\u0645\u064a\u0646 \u064a\u0627\u0645\u0627\u0644"},"shortNameTranslation":{"ar":"\u0644. \u064a\u0627\u0645\u0627\u0644"}}},"isHome":true,"shotType":"miss","situation":"assisted","playerCoordinates":{"x":20.1,"y":68,"z":0},"bodyPart":"left-foot","goalMouthLocation":"close-high","goalMouthCoordinates":{"x":0,"y":55.1,"z":58.3},"xg":0.016396386548877,"id":3433358,"time":81,"timeSeconds":4856,"draw":{"start":{"x":68,"y":20.1},"end":{"x":44.9,"y":0},"goal":{"x":44.9,"y":41.7}},"reversedPeriodTime":10,"reversedPeriodTimeSeconds":544,"incidentType":"shot"},{"player":{"name":"Theo Hern\u00e1ndez","slug":"theo-hernandez","shortName":"T. Hern\u00e1ndez","position":"D","jerseyNumber":"19","userCount":20429,"id":788027,"fieldTranslations":{"nameTranslation":{"ar":"\u062b\u064a\u0648"},"shortNameTranslation":{"ar":"\u062b\u064a\u0648"}}},"isHome":false,"shotType":"miss","situation":"regular","playerCoordinates":{"x":15.1,"y":44.8,"z":0},"bodyPart":"right-foot","goalMouthLocation":"high","goalMouthCoordinates":{"x":0,"y":49.4,"z":72.2},"xg":0.13599471747875,"id":3433356,"time":76,"timeSeconds":4508,"draw":{"start":{"x":44.8,"y":15.1},"end":{"x":50.6,"y":0},"goal":{"x":50.6,"y":27.8}},"reversedPeriodTime":15,"reversedPeriodTimeSeconds":892,"incidentType":"shot"},{"player":{"name":"Dayot Upamecano","slug":"dayot-upamecano","shortName":"D. Upamecano","position":"D","jerseyNumber":"2","userCount":10268,"id":798583,"fieldTranslations":{"nameTranslation":{"ar":"\u0623\u0648\u0628\u0627\u0645\u064a\u0643\u0627\u0646\u0648, \u062f\u0627\u064a\u0648\u062a"},"shortNameTranslation":{"ar":"\u062f. \u0623\u0648\u0628\u0627\u0645\u064a\u0643\u0627\u0646\u0648"}}},"isHome":false,"shotType":"miss","situation":"corner","playerCoordinates":{"x":4.5,"y":57.7,"z":0},"bodyPart":"head","goalMouthLocation":"right","goalMouthCoordinates":{"x":0,"y":40.7,"z":27.8},"xg":0.12655760347843,"id":3433336,"time":63,"timeSeconds":3747,"draw":{"start":{"x":57.7,"y":4.5},"end":{"x":59.3,"y":0},"goal":{"x":59.3,"y":72.2}},"reversedPeriodTime":28,"reversedPeriodTimeSeconds":1653,"incidentType":"shot"},{"player":{"name":"Kylia ...

# %%
data = json.loads(stats)
data
# Out:
# {'shotmap': [{'player': {'name': 'Antoine Griezmann',
#     'slug': 'antoine-griezmann',
#     'shortName': 'A. Griezmann',
#     'position': 'F',
#     'jerseyNumber': '7',
#     'userCount': 110394,
#     'id': 85859,
#     'fieldTranslations': {'nameTranslation': {'ar': 'غريزمان, انطوان'},
#      'shortNameTranslation': {'ar': 'ا. غريزمان'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 10.5, 'y': 58.3, 'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 49.4, 'z': 19},
#    'blockCoordinates': {'x': 9, 'y': 57.2, 'z': 0},
#    'xg': 0.02813040651381,
#    'id': 3433360,
#    'time': 90,
#    'addedTime': 5,
#    'timeSeconds': 5679,
#    'draw': {'start': {'x': 58.3, 'y': 10.5},
#     'block': {'x': 57.2, 'y': 9},
#     'end': {'x': 50.6, 'y': 0},
#     'goal': {'x': 50.6, 'y': 81}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 621,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Kylian Mbappé',
#     'slug': 'kylian-mbappe',
#     'shortName': 'K. Mbappé',
#     'position': 'F',
#     'jerseyNumber': '9',
#     'userCount': 508440,
#     'id': 826643,
#     'fieldTranslations': {'nameTranslation': {'ar': 'كيليان مباب'},
#      'shortNameTranslation': {'ar': 'ك. مباب'}}},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 14.1, 'y': 39, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'high',
#    'goalMouthCoordinates': {'x': 0, 'y': 54.6, 'z': 66.7},
#    'xg': 0.079102113842964,
#    'id': 3433359,
#    'time': 86,
#    'timeSeconds': 5124,
#    'draw': {'start': {'x': 39, 'y': 14.1},
#     'end': {'x': 45.4, 'y': 0},
#     'goal': {'x': 45.4, 'y': 33.3}},
#    'reversedPeriodTime': 5,
#    'reversedPeriodTimeSeconds': 276,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Lamine Yamal',
#     'firstName': 'Lamine Yamal',
#     'slug': 'lamine-yamal',
#     'shortName': 'Lamine Yamal',
#     'position': 'F',
#     'jerseyNumber': '27',
#     'userCount': 164506,
#     'id': 1402912,
#     'fieldTranslations': {'nameTranslation': {'ar': 'لامين يامال'},
#      'shortNameTranslation': {'ar': 'ل. يامال'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 20.1, 'y': 68, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'close-high',
#    'goalMouthCoordinates': {'x': 0, 'y': 55.1, 'z': 58.3},
#    'xg': 0.016396386548877,
#    'id': 3433358,
#    'time': 81,
#    'timeSeconds': 4856,
#    'draw': {'start': {'x': 68, 'y': 20.1},
#     'end': {'x': 44.9, 'y': 0},
#     'goal': {'x': 44.9, 'y': 41.7}},
#    'reversedPeriodTime': 10,
#    'reversedPeriodTimeSeconds': 544,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Theo Hernández',
#     'slug': 'theo-hernandez',
#     'shortName': 'T. Hernández',
#     'position': 'D',
#     'jerseyNumber': '19',
#     'userCount': 20429,
#     'id': 788027,
#     'fieldTranslations': {'nameTranslation': {'ar': 'ثيو'},
#      'shortNameTranslation': {'ar': 'ثيو'}}},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'regular',
#    'playerCoordinates': {'x': 15.1, 'y': 44.8, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'high',
#    'goalMouthCoordinates': {'x': 0, 'y': 49.4, 'z': 72.2},
#    'xg': 0.13599471747875,
#    'id': 3433356,
#    'time': 76,
#    'timeSeconds': 4508,
#    'draw': {'start': {'x': 44.8, 'y': 15.1},
#     'end': {'x': 50.6, 'y': 0},
#     'goal': {'x': 50.6, 'y': 27.8}},
#    'reversedPeriodTime': 15,
#    'reversedPeriodTimeSeconds': 892,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Dayot Upamecano',
#     'slug': 'dayot-upamecano',
#     'shortName': 'D. Upamecano',
#     'position': 'D',
#     'jerseyNumber': '2',
#     'userCount': 10268,
#     'id': 798583,
#     'fieldTranslations': {'nameTranslation': {'ar': 'أوباميكانو, دايوت'},
#      'shortNameTranslation': {'ar': 'د. أوباميكانو'}}},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 4.5, 'y': 57.7, 'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'right',
#    'goalMouthCoordinates': {'x': 0, 'y': 40.7, 'z': 27.8},
#    'xg': 0.12655760347843,
#    'id': 3433336,
#    'time': 63,
#    'timeSeconds': 3747,
#    'draw': {'start': {'x': 57.7, 'y': 4.5},
#     'end': {'x': 59.3, 'y': 0},
#     'goal': {'x': 59.3, 'y': 72.2}},
#    'reversedPeriodTime': 28,
#    'reversedPeriodTimeSeconds': 1653,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Kylian Mbappé',
#     'slug': 'kylian-mbappe',
#     'shortName': 'K. Mbappé',
#     'position': 'F',
#     'jerseyNumber': '9',
#     'userCount': 508440,
#     'id': 826643,
#     'fieldTranslations': {'nameTranslation': {'ar': 'كيليان مباب'},
#      'shortNameTranslation': {'ar': 'ك. مباب'}}},
#    'isHome': False,
#    'shotType': 'save',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 9.5, 'y': 27.4, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 51.4, 'z': 1.3},
#    'blockCoordinates': {'x': 1.8, 'y': 45.1, 'z': 0},
#    'xg': 0.028828816488385,
#    'xgot': 0.054,
#    'id': 3433335,
#    'time': 56,
#    'timeSeconds': 3359,
#    'draw': {'start': {'x': 27.4, 'y': 9.5},
#     'block': {'x': 45.1, 'y': 1.8},
#     'end': {'x': 48.6, 'y': 0},
#     'goal': {'x': 48.6, 'y': 98.7}},
#    'reversedPeriodTime': 35,
#    'reversedPeriodTimeSeconds': 2041,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Aurélien Tchouaméni',
#     'slug': 'aurelien-tchouameni',
#     'shortName': 'A. Tchouaméni',
#     'position': 'M',
#     'jerseyNumber': '18',
#     'userCount': 65744,
#     'id': 859025,
#     'fieldTranslations': {'nameTranslation': {'ar': 'أوريلين تشواميني'},
#      'shortNameTranslation': {'ar': 'أ. تشواميني'}}},
#    'isHome': False,
#    'shotType': 'save',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 8.5, 'y': 50.9, 'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 50.7, 'z': 13.9},
#    'blockCoordinates': {'x': 1.6, 'y': 50.4, 'z': 0},
#    'xg': 0.10148026794195,
#    'xgot': 0.0286,
#    'id': 3433334,
#    'time': 53,
#    'timeSeconds': 3167,
#    'draw': {'start': {'x': 50.9, 'y': 8.5},
#     'block': {'x': 50.4, 'y': 1.6},
#     'end': {'x': 49.3, 'y': 0},
#     'goal': {'x': 49.3, 'y': 86.1}},
#    'reversedPeriodTime': 38,
#    'reversedPeriodTimeSeconds': 2233,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Lamine Yamal',
#     'firstName': 'Lamine Yamal',
#     'slug': 'lamine-yamal',
#     'shortName': 'Lamine Yamal',
#     'position': 'F',
#     'jerseyNumber': '27',
#     'userCount': 164506,
#     'id': 1402912,
#     'fieldTranslations': {'nameTranslation': {'ar': 'لامين يامال'},
#      'shortNameTranslation': {'ar': 'ل. يامال'}}},
#    'isHome': True,
#    'shotType': 'block',
#    'situation': 'fast-break',
#    'playerCoordinates': {'x': 20.6, 'y': 63.6, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 52.4, 'z': 19},
#    'blockCoordinates': {'x': 18.9, 'y': 62.3, 'z': 0},
#    'xg': 0.036124393343925,
#    'id': 3433312,
#    'time': 40,
#    'timeSeconds': 2398,
#    'draw': {'start': {'x': 63.6, 'y': 20.6},
#     'block': {'x': 62.3, 'y': 18.9},
#     'end': {'x': 47.6, 'y': 0},
#     'goal': {'x': 47.6, 'y': 81}},
#    'reversedPeriodTime': 6,
#    'reversedPeriodTimeSeconds': 302,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Fabián Ruiz',
#     'slug': 'fabian-ruiz',
#     'shortName': 'F. Ruiz',
#     'position': 'M',
#     'jerseyNumber': '8',
#     'userCount': 6867,
#     'id': 784655,
#     'fieldTranslations': {'nameTranslation': {'ar': 'فابيان رويز'},
#      'shortNameTranslation': {'ar': 'ف. رويز'}}},
#    'isHome': True,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 18.6, 'y': 48.9, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 51, 'z': 19},
#    'blockCoordinates': {'x': 12.4, 'y': 48.9, 'z': 0},
#    'xg': 0.075777962803841,
#    'id': 3433292,
#    'time': 36,
#    'timeSeconds': 2133,
#    'draw': {'start': {'x': 48.9, 'y': 18.6},
#     'block': {'x': 48.9, 'y': 12.4},
#     'end': {'x': 49, 'y': 0},
#     'goal': {'x': 49, 'y': 81}},
#    'reversedPeriodTime': 10,
#    'reversedPeriodTimeSeconds': 567,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Dani Olmo',
#     'slug': 'dani-olmo',
#     'shortName': 'D. Olmo',
#     'position': 'M',
#     'jerseyNumber': '7',
#     'userCount': 13196,
#     'id': 789071,
#     'fieldTranslations': {'nameTranslation': {'ar': 'أولمو, داني'},
#      'shortNameTranslation': {'ar': 'د. أولمو'}}},
#    'isHome': True,
#    'shotType': 'goal',
#    'goalType': 'regular',
#    'situation': 'regular',
#    'playerCoordinates': {'x': 8, 'y': 65.4, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 49.7, 'z': 15.8},
#    'xg': 0.12214437872171,
#    'xgot': 0.0282,
#    'id': 3433265,
#    'time': 25,
#    'timeSeconds': 1463,
#    'draw': {'start': {'x': 65.4, 'y': 8},
#     'end': {'x': 50.3, 'y': 0},
#     'goal': {'x': 50.3, 'y': 84.2}},
#    'reversedPeriodTime': 21,
#    'reversedPeriodTimeSeconds': 1237,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Lamine Yamal',
#     'firstName': 'Lamine Yamal',
#     'slug': 'lamine-yamal',
#     'shortName': 'Lamine Yamal',
#     'position': 'F',
#     'jerseyNumber': '27',
#     'userCount': 164506,
#     'id': 1402912,
#     'fieldTranslations': {'nameTranslation': {'ar': 'لامين يامال'},
#      'shortNameTranslation': {'ar': 'ل. يامال'}}},
#    'isHome': True,
#    'shotType': 'goal',
#    'goalType': 'regular',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 24.6, 'y': 62.7, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 53.9, 'z': 19},
#    'xg': 0.023169355466962,
#    'xgot': 0.3761,
#    'id': 3433264,
#    'time': 21,
#    'timeSeconds': 1214,
#    'draw': {'start': {'x': 62.7, 'y': 24.6},
#     'end': {'x': 46.1, 'y': 0},
#     'goal': {'x': 46.1, 'y': 81}},
#    'reversedPeriodTime': 25,
#    'reversedPeriodTimeSeconds': 1486,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Kylian Mbappé',
#     'slug': 'kylian-mbappe',
#     'shortName': 'K. Mbappé',
#     'position': 'F',
#     'jerseyNumber': '9',
#     'userCount': 508440,
#     'id': 826643,
#     'fieldTranslations': {'nameTranslation': {'ar': 'كيليان مباب'},
#      'shortNameTranslation': {'ar': 'ك. مباب'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 14.1, 'y': 36.8, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 52.8, 'z': 19},
#    'blockCoordinates': {'x': 7, 'y': 42.1, 'z': 0},
#    'xg': 0.028981354087591,
#    'id': 3433263,
#    'time': 19,
#    'timeSeconds': 1095,
#    'draw': {'start': {'x': 36.8, 'y': 14.1},
#     'block': {'x': 42.1, 'y': 7},
#     'end': {'x': 47.2, 'y': 0},
#     'goal': {'x': 47.2, 'y': 81}},
#    'reversedPeriodTime': 27,
#    'reversedPeriodTimeSeconds': 1605,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Kylian Mbappé',
#     'slug': 'kylian-mbappe',
#     'shortName': 'K. Mbappé',
#     'position': 'F',
#     'jerseyNumber': '9',
#     'userCount': 508440,
#     'id': 826643,
#     'fieldTranslations': {'nameTranslation': {'ar': 'كيليان مباب'},
#      'shortNameTranslation': {'ar': 'ك. مباب'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'free-kick',
#    'playerCoordinates': {'x': 27, 'y': 54.3, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 50.2, 'z': 19},
#    'blockCoordinates': {'x': 18.5, 'y': 52.9, 'z': 0},
#    'xg': 0.045754782855511,
#    'id': 3433262,
#    'time': 16,
#    'timeSeconds': 943,
#    'draw': {'start': {'x': 54.3, 'y': 27},
#     'block': {'x': 52.9, 'y': 18.5},
#     'end': {'x': 49.8, 'y': 0},
#     'goal': {'x': 49.8, 'y': 81}},
#    'reversedPeriodTime': 30,
#    'reversedPeriodTimeSeconds': 1757,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Randal Kolo Muani',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'randal-kolo-muani',
#     'shortName': 'R. K. Muani',
#     'position': 'F',
#     'jerseyNumber': '23',
#     'userCount': 12394,
#     'id': 871706,
#     'fieldTranslations': {'nameTranslation': {'ar': 'راندال كولو مواني'},
#      'shortNameTranslation': {'ar': 'ر. ك. مواني'}}},
#    'isHome': False,
#    'shotType': 'goal',
#    'goalType': 'regular',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 4.9, 'y': 52.6, 'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'high-right',
#    'goalMouthCoordinates': {'x': 0, 'y': 45.7, 'z': 23.4},
#    'xg': 0.52247798442841,
#    'xgot': 0.9486,
#    'id': 3433261,
#    'time': 9,
#    'timeSeconds': 480,
#    'draw': {'start': {'x': 52.6, 'y': 4.9},
#     'end': {'x': 54.3, 'y': 0},
#     'goal': {'x': 54.3, 'y': 76.6}},
#    'reversedPeriodTime': 37,
#    'reversedPeriodTimeSeconds': 2220,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Fabián Ruiz',
#     'slug': 'fabian-ruiz',
#     'shortName': 'F. Ruiz',
#     'position': 'M',
#     'jerseyNumber': '8',
#     'userCount': 6867,
#     'id': 784655,
#     'fieldTranslations': {'nameTranslation': {'ar': 'فابيان رويز'},
#      'shortNameTranslation': {'ar': 'ف. رويز'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 2.4, 'y': 44.7, 'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'close-high',
#    'goalMouthCoordinates': {'x': 0, 'y': 47.9, 'z': 58.3},
#    'xg': 0.53966546058655,
#    'id': 3433260,
#    'time': 5,
#    'timeSeconds': 288,
#    'draw': {'start': {'x': 44.7, 'y': 2.4},
#     'end': {'x': 52.1, 'y': 0},
#     'goal': {'x': 52.1, 'y': 41.7}},
#    'reversedPeriodTime': 41,
#    'reversedPeriodTimeSeconds': 2412,
#    'incidentType': 'shot'}]}

# %%
# Parse the JSON response
data = json.loads(stats)
data

df_players = pd.json_normalize(data['shotmap'])
df_players['Team'] = np.where(df_players['isHome'] == True, 'Home', 'Away')
columns_to_drop = ['isHome', 'player.fieldTranslations.nameTranslation.ar',
                   'player.fieldTranslations.shortNameTranslation.ar','player.firstName',
                   'player.lastName','player.slug','player.shortName']
df_players.drop(columns=columns_to_drop, inplace=True)

# Ensure 'Team' is included only once in the list of columns
unique_columns = ['player.name', 'Team'] + [col for col in df_players.columns if col not in ['player.name', 'Team']]
df_players = df_players.reindex(columns=unique_columns)

# Sort the DataFrame by 'Team' to have 'Home' teams listed first
df_players_sorted = df_players.sort_values(by='Team', ascending=False)

# Fill NaN values with 0
df_players_sorted.fillna(0, inplace=True)
df_players_sorted.reset_index(drop=True, inplace=True)


df_players_sorted
# Out:
#             player.name  Team shotType   situation    bodyPart  \
# 0          Lamine Yamal  Home     miss    assisted   left-foot
# 1          Lamine Yamal  Home    block  fast-break   left-foot
# 2           Fabián Ruiz  Home    block    assisted   left-foot
# 3             Dani Olmo  Home     goal     regular  right-foot
# 4          Lamine Yamal  Home     goal    assisted   left-foot
# 5           Fabián Ruiz  Home     miss    assisted        head
# 6     Antoine Griezmann  Away    block    assisted        head
# 7         Kylian Mbappé  Away     miss    assisted  right-foot
# 8        Theo Hernández  Away     miss     regular  right-foot
# 9       Dayot Upamecano  Away     miss      corner        head
# 10        Kylian Mbappé  Away     save    assisted  right-foot
# 11  Aurélien Tchouaméni  Away     save      corner        head
# 12        Kylian Mbappé  Away    block    assisted  right-foot
# 13        Kylian Mbappé  Away    block   free-kick  right-foot
# 14    Randal Kolo Muani  Away     goal    assisted        head
#
#    goalMouthLocation        xg       id  time  addedTime  ...  draw.start.x  \
# 0         close-high  0.016396  3433358    81        0.0  ...          68.0
# 1           low-left  0.036124  3433312    40        0.0  ...          63.6
# 2         low-centre  0.075778  3433292    36        0.0  ...          48.9
# 3         low-centre  0.122144  3433265    25        0.0  ...          65.4
# 4           low-left  0.023169  3433264    21        0.0  ...          62.7
# 5         close-high  0.539665  3433260     5        0.0  ...          44.7
# 6         low-centre  0.028130  3433360    90        5.0  ...          58.3
# 7               high  0.079102  3433359    86        0.0  ...          39.0
# 8               high  0.135995  3433356    76        0.0  ...          44.8
# 9              right  0.126558  3433336    63        0.0  ...          57.7
# 10        low-centre  0.028829  3433335    56        0.0  ...          27.4
# 11        low-centre  0.101480  3433334    53        0.0  ...          50.9
# 12          low-left  0.028981  3433263    19        0.0  ...          36.8
# 13        low-centre  0.045755  3433262    16        0.0  ...          54.3
# 14        high-right  0.522478  3433261     9        0.0  ...          52.6
#
#     draw.start.y  draw.block.x draw.block.y draw.end.x draw.end.y  \
# 0           20.1           0.0          0.0       44.9          0
# 1           20.6          62.3         18.9       47.6          0
# 2           18.6          48.9         12.4       49.0          0
# 3            8.0           0.0          0.0       50.3          0
# 4           24.6           0.0          0.0       46.1          0
# 5            2.4           0.0          0.0       52.1          0
# 6           10.5          57.2          9.0       50.6          0
# 7           14.1           0.0          0.0       45.4          0
# 8           15.1           0.0          0.0       50.6          0
# 9            4.5           0.0          0.0       59.3          0
# 10           9.5          45.1          1.8       48.6          0
# 11           8.5          50.4          1.6       49.3          0
# 12          14.1          42.1          7.0       47.2          0
# 13          27.0          52.9         18.5       49.8          0
# 14           4.9           0.0          0.0       54.3          0
#
#     draw.goal.x  draw.goal.y    xgot  goalType
# 0          44.9         41.7  0.0000         0
# 1          47.6         81.0  0.0000         0
# 2          49.0         81.0  0.0000         0
# 3          50.3         84.2  0.0282   regular
# 4          46.1         81.0  0.3761   regular
# 5          52.1         41.7  0.0000         0
# 6          50.6         81.0  0.0000         0
# 7          45.4         33.3  0.0000         0
# 8          50.6         27.8  0.0000         0
# 9          59.3         72.2  0.0000         0
# 10         48.6         98.7  0.0540         0
# 11         49.3         86.1  0.0286         0
# 12         47.2         81.0  0.0000         0
# 13         49.8         81.0  0.0000         0
# 14         54.3         76.6  0.9486   regular
#
# [15 rows x 37 columns]

# %%
df_players_sorted.to_csv('spain-france_shotmap.csv', index=False)
